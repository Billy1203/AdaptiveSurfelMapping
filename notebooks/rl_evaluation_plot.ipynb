# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
psnr_list = [14.647802760214326, 14.405763313197147, 13.840953821254537, 13.40769131989395, 12.995442950432581, 12.92344719247539, 12.851088236003958, 13.604965258046187, 16.000674357431354, 15.824138107569354, 16.633491265991736, 16.837309174486123, 15.175717207839629, 15.828756935724117, 16.04241216717494]

ssim_list = [0.4335394226101032, 0.3728532735680816, 0.39483504648137785, 0.32661627943143795, 0.41660010459336755, 0.42823410920055927, 0.433883941398365, 0.41644348655834657, 0.4796862644146394, 0.4159040415081483, 0.5268485565008675, 0.492734719675334, 0.34660964666884203, 0.29898934498756075, 0.33979085838519985]

lpips_list = [0.12376961, 0.13548431, 0.13770097, 0.15414289, 0.11847562, 0.12621582, 0.1895135, 0.21626273, 0.16807617, 0.16663405, 0.14535506, 0.17119308, 0.23249936, 0.17795211, 0.16860847]

# %%
plt.figure()
plt.plot(np.array(psnr_list)/10, label='psnr')
plt.plot(np.array(ssim_list), label='ssim')
plt.plot(np.array(lpips_list)*10, label='lpips')
plt.legend()
plt.show()
